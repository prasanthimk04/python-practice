# %%
import pandas as pd

data = {
    "Name": ["Ravi", "Priya", "Arun", "Sneha", "Kiran"],
    "Age": [25, 28, 24, 30, 27],
    "Marks": [78, 92, 65, 88, 95],
    "City": ["Bangalore", "Hyderabad", "Bangalore", "Chennai", "Hyderabad"]
}

df = pd.DataFrame(data)
print(df)
print("---------------------------------")

# Exercise 1: Display the first 3 rows.
print(df.head(3))
print("---------------------------------")

# Exercise 2: Display only the Name column.
print(df.columns)
print("---------------------------------")

# Exercise 3: Display Name and Marks.
print(df[['Name','Marks']])
print("---------------------------------")

# Exercise 4: Find students whose Marks > 80.
print("whose Marks > 80",df[df['Marks']> 80])

# Exercise 5: Count how many students scored above 80.

# Exercise 6: Find the average marks.

# Exercise 7: Find the highest marks.

# Exercise 8: Find students from "Bangalore".

# Exercise 9: Sort students by Marks from highest to lowest.

# Exercise 10: Add a new column called Passed:
# Out:
#     Name  Age  Marks       City
# 0   Ravi   25     78  Bangalore
# 1  Priya   28     92  Hyderabad
# 2   Arun   24     65  Bangalore
# 3  Sneha   30     88    Chennai
# 4  Kiran   27     95  Hyderabad
# ---------------------------------
#     Name  Age  Marks       City
# 0   Ravi   25     78  Bangalore
# 1  Priya   28     92  Hyderabad
# 2   Arun   24     65  Bangalore
# ---------------------------------
# Index(['Name', 'Age', 'Marks', 'City'], dtype='str')
# ---------------------------------
#     Name  Marks
# 0   Ravi     78
# 1  Priya     92
# 2   Arun     65
# 3  Sneha     88
# 4  Kiran     95
# ---------------------------------
# whose Marks > 80     Name  Age  Marks       City
# 1  Priya   28     92  Hyderabad
# 3  Sneha   30     88    Chennai
# 4  Kiran   27     95  Hyderabad
